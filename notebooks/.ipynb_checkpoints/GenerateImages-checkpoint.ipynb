# %%
include("../src/main.jl")
# Out:
# main (generic function with 1 method)

# %%
#Analytic parameters


## REMEMBER TO CHANGE BLACK HOLE MASS IN PARAMETERS.JL

#Setting up the parameters
#Observer distance in Rg
ro = 1000.0
#Observer inclination in degrees
th = 60.0

#Observer azimuth in degrees
phi = 0.0

# Size of the screen in Rg in both directions
DXsize = 30.0
DYsize = 30.0

# Observer fov in radians (this can be understood as size of the plane camera sees over the distance ro)
# This should be atan, but for small angles it is approximately equal to the angle itself
fovx = DXsize/ro
fovy = DYsize/ro

# Number of pixels in the x and y direction. The number of geodesics calculated will be res^2
res = 128
pixels_x = 128
pixels_y = 128
# Distance to the source in parsecs
SourceD = 7.778e3 * PC
bhspin = 0.9
Rout = 1000.0
Rstop = 10000.0
Rh = 1 + sqrt(1. - bhspin * bhspin);

cstartx = [0.0, log(Rh), 0.0, 0.0]
cstopx = [0.0, log(1000.0), 1.0, 2.0 * π]
# Frequency observed by the camera in Hz
freq = 230e9
# Out:
# 2.3e11

# %%
#THIN DISK PARAMETERS


## REMEMBER TO CHANGE BLACK HOLE MASS IN PARAMETERS.JL

#Setting up the parameters
#Observer distance in Rg
ro = 10000.0
#Observer inclination in degrees
th = 60.0

#Observer azimuth in degrees
phi = 0.0

# Size of the screen in Rg in both directions
DXsize = 40.0
DYsize = 40.0

# Observer fov in radians (this can be understood as size of the plane camera sees over the distance ro)
# This should be atan, but for small angles it is approximately equal to the angle itself
fovx = DXsize/ro
fovy = DYsize/ro

# Number of pixels in the x and y direction. The number of geodesics calculated will be res^2
res = 256
pixels_x = 256
pixels_y = 256

# Distance to the source in parsecs
SourceD = 0.05 * PC
Rout = 1000.0
Rstop = 10000.0

# Frequency observed by the camera in Hz
freq = 2.417989e17#230e9

# %%
# Find camera in native coordinates
Xcamera = MVec4(camera_position(ro, th, phi, bhspin, Rout))

# Scales the intensity of each pixel by the real size of each pixel
scale_factor = CalculateScaleFactor(DXsize, DYsize, pixels_x, pixels_y, SourceD, L_unit)

maxnstep = 15000
# Generate geodesics
println("Utilizing $(Threads.nthreads()) threads for geodesic calculation.")
freq_unitless = freq * HPL/(ME * CL * CL)  # Convert frequency to unitless
Image = zeros(Float64, pixels_x, pixels_y)
for i in 0:(pixels_x - 1)
    println("Processing row $i out of $(pixels_x)")

    Threads.@threads for j in 0:(pixels_y - 1)
        traj = Vector{OfTraj}()
        sizehint!(traj, maxnstep)

        nstep = get_pixel(traj, i, j, Xcamera, maxnstep, fovx, fovy, freq_unitless, pixels_x, pixels_y, bhspin, Rh, Rout, Rstop)

        resize!(traj, length(traj))
        integrate_emission!(traj, length(traj), Image, i + 1, j + 1, freq, bhspin)

    end
end
Image *= freq^3;
# Out:
# Utilizing 1 threads for geodesic calculation.
# Processing row 0 out of 128
# Processing row 1 out of 128
# Processing row 2 out of 128
# Processing row 3 out of 128
# Processing row 4 out of 128
# Processing row 5 out of 128
# Processing row 6 out of 128
# Processing row 7 out of 128
# Processing row 8 out of 128
# Processing row 9 out of 128
# Processing row 10 out of 128
# Processing row 11 out of 128
# Processing row 12 out of 128
# Processing row 13 out of 128
# Processing row 14 out of 128
# Processing row 15 out of 128
# Processing row 16 out of 128
# Processing row 17 out of 128
# Processing row 18 out of 128
# Processing row 19 out of 128
# Processing row 20 out of 128
# Processing row 21 out of 128
# Processing row 22 out of 128
# Processing row 23 out of 128
# Processing row 24 out of 128
# Processing row 25 out of 128
# Processing row 26 out of 128
# Processing row 27 out of 128
# Processing row 28 out of 128
# Processing row 29 out of 128
# Processing row 30 out of 128
# Processing row 31 out of 128
# Processing row 32 out of 128
# Processing row 33 out of 128
# Processing row 34 out of 128
# Processing row 35 out of 128
# Processing row 36 out of 128
# Processing row 37 out of 128
# Processing row 38 out of 128
# Processing row 39 out of 128
# Processing row 40 out of 128
# Processing row 41 out of 128
# Processing row 42 out of 128
# Processing row 43 out of 128
# Processing row 44 out of 128
# Processing row 45 out of 128
# Processing row 46 out of 128
# Processing row 47 out of 128
# Processing row 48 out of 128
# Processing row 49 out of 128
# Processing row 50 out of 128
# Processing row 51 out of 128
# Processing row 52 out of 128
# Processing row 53 out of 128
# Processing row 54 out of 128
# Processing row 55 out of 128
# Processing row 56 out of 128
# Processing row 57 out of 128
# Processing row 58 out of 128
# Processing row 59 out of 128
# Processing row 60 out of 128
# Processing row 61 out of 128
# Processing row 62 out of 128
# Processing row 63 out of 128
# Processing row 64 out of 128
# Processing row 65 out of 128
# Processing row 66 out of 128
# Processing row 67 out of 128
# Processing row 68 out of 128
# Processing row 69 out of 128
# Processing row 70 out of 128
# Processing row 71 out of 128
# Processing row 72 out of 128
# Processing row 73 out of 128
# Processing row 74 out of 128
# Processing row 75 out of 128
# Processing row 76 out of 128
# Processing row 77 out of 128
# Processing row 78 out of 128
# Processing row 79 out of 128
# Processing row 80 out of 128
# Processing row 81 out of 128
# Processing row 82 out of 128
# Processing row 83 out of 128
# Processing row 84 out of 128
# Processing row 85 out of 128
# Processing row 86 out of 128
# Processing row 87 out of 128
# Processing row 88 out of 128
# Processing row 89 out of 128
# Processing row 90 out of 128
# Processing row 91 out of 128
# Processing row 92 out of 128
# Processing row 93 out of 128
# Processing row 94 out of 128
# Processing row 95 out of 128
# Processing row 96 out of 128
# Processing row 97 out of 128
# Processing row 98 out of 128
# Processing row 99 out of 128
# Processing row 100 out of 128
# Processing row 101 out of 128
# Processing row 102 out of 128
# Processing row 103 out of 128
# Processing row 104 out of 128
# Processing row 105 out of 128
# Processing row 106 out of 128
# Processing row 107 out of 128
# Processing row 108 out of 128
# Processing row 109 out of 128
# Processing row 110 out of 128
# Processing row 111 out of 128
# Processing row 112 out of 128
# Processing row 113 out of 128
# Processing row 114 out of 128
# Processing row 115 out of 128
# Processing row 116 out of 128
# Processing row 117 out of 128
# Processing row 118 out of 128
# Processing row 119 out of 128
# Processing row 120 out of 128
# Processing row 121 out of 128
# Processing row 122 out of 128
# Processing row 123 out of 128
# Processing row 124 out of 128
# Processing row 125 out of 128
# Processing row 126 out of 128
# Processing row 127 out of 128

# %%
OutputStokesParameters(Image, freq, scale_factor, res, SourceD)
# Out:
# Image processing complete. Calculating total flux and averages...
# Scale = 3.434506295210955e+00
# imax = 46, jmax = 60, Imax = 9.696439589940023e-7, Iavg = 4.604373078867924e-7
# Using freq_cgs = 2.3e11, Ftot = 0.02590924525547004
# nuLnu = 4.313497472983339e32

# %%
using CairoMakie
using Printf

d_kpc = 7.78
d_cm = d_kpc * 3.086e21           # distance in cm
fov_rg = 30                       # field of view in gravitational radii
half_fov_rg = fov_rg / 2

# Angular resolution
theta_rad = (half_fov_rg * L_unit) / d_cm   # half FOV in radians
theta_μas = theta_rad * MUAS_PER_RAD        # convert to μas
xlims = (-theta_μas, theta_μas)
ylims = (-theta_μas, theta_μas)

# Generate mock image (or load your 128x128 array here)
img = Image

# Axes
Ny, Nx = size(img)
x = range(xlims[1], xlims[2], length=Nx)
y = range(ylims[1], ylims[2], length=Ny)

# Plot
fig = Figure(size = (600, 500))
ax = Axis(fig[1, 1],
    xlabel = "Relative R.A [μas]",
    ylabel = "Relative Dec [μas]",
    xlabelsize=24,
    ylabelsize=24,
    xticklabelsize=20,
    yticklabelsize=20,
    limits = (xlims, ylims)
)

# Heatmap with color range
crange = extrema(img)
hm = heatmap!(ax, x, y, img; colormap=:hot, colorrange=crange)

# Colorbar
Colorbar(fig[1, 2], hm;
    label = "Intensity",
    labelsize = 20,
    ticklabelsize = 16,
    width = 15
)

fig
